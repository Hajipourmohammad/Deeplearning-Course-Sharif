# %% [markdown]
# # Impor Packages

# %%
import os
import torch
import pandas as pd
from torchvision.io import read_image
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
import torch.nn as nn
import torchvision.transforms as transforms
import torchvision.datasets as dsets
from torch.autograd import Variable
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
from torchvision.transforms import ToTensor, Lambda
import random
import torchvision.transforms as T
import torchvision.transforms as transforms

# %% [markdown]
# # (A) : Loading Data

# %%
df_train = pd.read_csv('./Data/HW2_data/Q3_train.csv')
df_test = pd.read_csv('./Data/HW2_data/Q3_test.csv')
df_train
# Out:
#        label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0          3     107     118     127     134     139     143     146     150
# 1          6     155     157     156     156     156     157     156     158
# 2          2     187     188     188     187     187     186     187     188
# 3          2     211     211     212     212     211     210     211     210
# 4         13     164     167     170     172     176     179     180     184
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 27450     13     189     189     190     190     192     193     193     193
# 27451     23     151     154     157     158     160     161     163     164
# 27452     18     174     174     174     174     174     175     175     174
# 27453     17     177     181     184     185     187     189     190     191
# 27454     23     179     180     180     180     182     181     182     183
#
#        pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  \
# 0         153  ...       207       207       207       207       206
# 1         158  ...        69       149       128        87        94
# 2         187  ...       202       201       200       199       198
# 3         210  ...       235       234       233       231       230
# 4         185  ...        92       105       105       108       133
# ...       ...  ...       ...       ...       ...       ...       ...
# 27450     193  ...       132       165        99        77        52
# 27451     166  ...       198       198       198       198       198
# 27452     173  ...       121       196       209       208       206
# 27453     191  ...       119        56        27        58       102
# 27454     182  ...       108       132       170       194       214
#
#        pixel780  pixel781  pixel782  pixel783  pixel784
# 0           206       206       204       203       202
# 1           163       175       103       135       149
# 2           199       198       195       194       195
# 3           226       225       222       229       163
# 4           163       157       163       164       179
# ...         ...       ...       ...       ...       ...
# 27450       200       234       200       222       225
# 27451       196       195       195       195       194
# 27452       204       203       202       200       200
# 27453        79        47        64        87        93
# 27454       203       197       205       209       215
#
# [27455 rows x 785 columns]

# %% [markdown]
# # (A) : Convert Dataframe To Numpy Array

# %%
train_percent = 0.8

df_train_np = df_train.to_numpy()
df_test_np = df_test.to_numpy()

x_train = df_train_np[:int(len(df_train_np) * train_percent),1:]
y_train = df_train_np[:int(len(df_train_np) * train_percent),:1]


x_val = df_train_np[int(len(df_train_np) * train_percent):,1:]
y_val = df_train_np[int(len(df_train_np) * train_percent):,:1]

x_test = df_test_np[:,1:]
y_test = df_test_np[:,:1]

print("Train: ", x_train.shape ,y_train.shape)
print("Validation: ", x_val.shape ,y_val.shape)
print("Test: " ,x_test.shape ,y_test.shape)
# Out:
# Train:  (21964, 784) (21964, 1)
# Validation:  (5491, 784) (5491, 1)
# Test:  (7172, 784) (7172, 1)

# %% [markdown]
# # (A) : Showing Some Samples From Dataset

# %%
figure = plt.figure(figsize=(8, 8))
rows_id = random.sample(range(0, x_train.shape[0]-1), 9)
j = 1
for i in rows_id:
    figure.add_subplot(3, 3, j)
    plt.axis("off")
    plt.imshow(x_train[i,:].reshape((28,28)), cmap="gray")
    j+=1

# %% [markdown]
# # (B) : Create Custom Dataset

# %%
class CustomDataset(Dataset):
    def __init__(self, X, Y, transform=None, target_transform=None):
        
        self.label = Y
        self.feature = X
        self.transform = transform
        self.target_transform = target_transform

    def __len__(self):
        return len(self.label)

    def __getitem__(self, idx):
        
        feature = self.feature[idx]/255.
        label = self.label[idx]
        
#         if self.transform:
#             feature = self.transform(feature)
            
#         if self.target_transform:
#             labels = self.target_transform(label)
            
        return feature, label

# %% [markdown]
# # (B) : Making Dataset Iterable

# %%
batch_size = 128

train_data = CustomDataset(x_train, y_train)
test_data = CustomDataset(x_test, y_test)
val_data = CustomDataset(x_val, y_val)


train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_data, batch_size=batch_size, shuffle=True)

# %% [markdown]
# # (B) : Create Model Class

# %%
class MyNet(nn.Module):
    def __init__(self):
        super(MyNet, self).__init__()
        self.mlp = nn.Sequential(
            nn.Linear(28*28, 512),
            nn.ReLU(),
            nn.Linear(512, 1024),
            nn.ReLU(),
            nn.Linear(1024, 512),
            nn.ReLU(),
            nn.Linear(512, 25)
        )

    def forward(self, x):
        logits = self.mlp(x)
        return logits

# %% [markdown]
# # (B) : Define Train & Test & Validation Loop

# %%
def train_loop(dataloader, model, loss_fn, optimizer, log):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    train_loss, train_acc = 0, 0
    for batch, (X, y) in enumerate(dataloader):
        
        pred = model(X.to(torch.float32).to(device))
        loss = loss_fn(pred, y.to(device).squeeze(1))
        
        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
        train_acc += (pred.argmax(1) == y.to(device).squeeze(1)).type(torch.float).sum().item()
            
    train_loss /= num_batches
    train_acc /= size
    
    log['train_loss'].append(train_loss)
    log['train_acc'].append(train_acc)
    
    print(f"Train Result: \n Accuracy: {(100*train_acc):>0.1f}%, Avg Train loss: {train_loss:>8f} \n")


def valid_loop(dataloader, model, loss_fn, log):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    valid_loss, valid_acc = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X.to(torch.float32).to(device))
            loss = loss_fn(pred, y.to(device).squeeze(1))
            
            valid_loss += loss.item()
            valid_acc += (pred.argmax(1) == y.to(device).squeeze(1)).type(torch.float).sum().item()

    valid_loss /= num_batches
    valid_acc /= size
    
    log['valid_loss'].append(valid_loss)
    log['valid_acc'].append(valid_acc)
    print(f"Validation Result: \n Accuracy: {(100*valid_acc):>0.1f}%, Avg Validation loss: {valid_loss:>8f} \n")

    
    
def test_loop(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, test_acc = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X.to(torch.float32).to(device))
            loss = loss_fn(pred, y.to(device).squeeze(1))
            
            test_loss += loss.item()
            test_acc += (pred.argmax(1) == y.to(device).squeeze(1)).type(torch.float).sum().item()

    test_loss /= num_batches
    test_acc /= size 
    print(f"Test Result: \n Accuracy: {(100*test_acc):>0.1f}%, Avg Test loss: {test_loss:>8f} \n")

# %% [markdown]
# # (B) : Instatiate Model Class Base On SGD

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
model_sgd = MyNet().to(device)

criterion = nn.CrossEntropyLoss()

lr_sgd = 0.01
epochs = 30
optimizer_sgd = torch.optim.SGD(model_sgd.parameters(), lr=lr_sgd, momentum=0.9)

# %% [markdown]
# # (B) : Training Process Based On SGD

# %%
log = {'train_loss':[], 'valid_loss' : [], 'train_acc' : [], 'valid_acc' : []}
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    model_sgd.train()
    train_loop(train_loader, model_sgd, criterion, optimizer_sgd, log)
    model_sgd.eval()
    valid_loop(val_loader, model_sgd, criterion, log)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Train Result:
#  Accuracy: 7.7%, Avg Train loss: 3.150784
#
# Validation Result:
#  Accuracy: 11.4%, Avg Validation loss: 2.988561
#
# Epoch 2
# -------------------------------
# Train Result:
#  Accuracy: 22.4%, Avg Train loss: 2.474191
#
# Validation Result:
#  Accuracy: 34.8%, Avg Validation loss: 1.969199
#
# Epoch 3
# -------------------------------
# Train Result:
#  Accuracy: 41.1%, Avg Train loss: 1.764752
#
# Validation Result:
#  Accuracy: 51.6%, Avg Validation loss: 1.429043
#
# Epoch 4
# -------------------------------
# Train Result:
#  Accuracy: 54.5%, Avg Train loss: 1.346487
#
# Validation Result:
#  Accuracy: 60.5%, Avg Validation loss: 1.136069
#
# Epoch 5
# -------------------------------
# Train Result:
#  Accuracy: 64.8%, Avg Train loss: 1.038577
#
# Validation Result:
#  Accuracy: 65.6%, Avg Validation loss: 0.982940
#
# Epoch 6
# -------------------------------
# Train Result:
#  Accuracy: 72.1%, Avg Train loss: 0.830877
#
# Validation Result:
#  Accuracy: 74.6%, Avg Validation loss: 0.728823
#
# Epoch 7
# -------------------------------
# Train Result:
#  Accuracy: 79.0%, Avg Train loss: 0.630221
#
# Validation Result:
#  Accuracy: 72.3%, Avg Validation loss: 0.796584
#
# Epoch 8
# -------------------------------
# Train Result:
#  Accuracy: 80.7%, Avg Train loss: 0.566378
#
# Validation Result:
#  Accuracy: 83.4%, Avg Validation loss: 0.471679
#
# Epoch 9
# -------------------------------
# Train Result:
#  Accuracy: 84.2%, Avg Train loss: 0.468129
#
# Validation Result:
#  Accuracy: 85.0%, Avg Validation loss: 0.420828
#
# Epoch 10
# -------------------------------
# Train Result:
#  Accuracy: 89.0%, Avg Train loss: 0.329576
#
# Validation Result:
#  Accuracy: 90.5%, Avg Validation loss: 0.272799
#
# Epoch 11
# -------------------------------
# Train Result:
#  Accuracy: 91.6%, Avg Train loss: 0.258456
#
# Validation Result:
#  Accuracy: 87.1%, Avg Validation loss: 0.365665
#
# Epoch 12
# -------------------------------
# Train Result:
#  Accuracy: 93.3%, Avg Train loss: 0.214315
#
# Validation Result:
#  Accuracy: 98.7%, Avg Validation loss: 0.080724
#
# Epoch 13
# -------------------------------
# Train Result:
#  Accuracy: 96.5%, Avg Train loss: 0.120848
#
# Validation Result:
#  Accuracy: 96.8%, Avg Validation loss: 0.101086
#
# Epoch 14
# -------------------------------
# Train Result:
#  Accuracy: 95.0%, Avg Train loss: 0.159180
#
# Validation Result:
#  Accuracy: 97.1%, Avg Validation loss: 0.091685
#
# Epoch 15
# -------------------------------
# Train Result:
#  Accuracy: 99.2%, Avg Train loss: 0.043234
#
# Validation Result:
#  Accuracy: 99.6%, Avg Validation loss: 0.030576
#
# Epoch 16
# -------------------------------
# Train Result:
#  Accuracy: 99.7%, Avg Train loss: 0.024755
#
# Validation Result:
#  Accuracy: 99.9%, Avg Validation loss: 0.019980
#
# Epoch 17
# -------------------------------
# Train Result:
#  Accuracy: 99.2%, Avg Train loss: 0.034479
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.013431
#
# Epoch 18
# -------------------------------
# Train Result:
#  Accuracy: 100.0%, Avg Train loss: 0.010519
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.009125
#
# Epoch 19
# -------------------------------
# Train Result:
#  Accuracy: 100.0%, Avg Train loss: 0.008651
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.006897
#
# Epoch 20
# -------------------------------
# Train Result:
#  Accuracy: 100.0%, Avg Train loss: 0.006143
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.009235
#
# Epoch 21
# -------------------------------
# Train Result:
#  Accuracy: 100.0%, Avg Train loss: 0.005196
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.005222
#
# Epoch 22
# -------------------------------
# Train Result:
#  Accuracy: 100.0%, Avg Train loss: 0.004808
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.004072
#
# Epoch 23
# -------------------------------
# Train Result:
#  Accuracy: 100.0%, Avg Train loss: 0.004007
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.004666
#
# Epoch 24
# -------------------------------
# Train Result:
#  Accuracy: 100.0%, Avg Train loss: 0.004209
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.003692
#
# Epoch 25
# -------------------------------
# Train Result:
#  Accuracy: 100.0%, Avg Train loss: 0.003331
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.003000
#
# Epoch 26
# -------------------------------
# Train Result:
#  Accuracy: 100.0%, Avg Train loss: 0.002917
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.003268
#
# Epoch 27
# -------------------------------
# Train Result:
#  Accuracy: 100.0%, Avg Train loss: 0.002662
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.002689
#
# Epoch 28
# -------------------------------
# Train Result:
#  Accuracy: 100.0%, Avg Train loss: 0.002525
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.002435
#
# Epoch 29
# -------------------------------
# Train Result:
#  Accuracy: 100.0%, Avg Train loss: 0.002508
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.002291
#
# Epoch 30
# -------------------------------
# Train Result:
#  Accuracy: 100.0%, Avg Train loss: 0.002099
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.002169
#
# Done!

# %% [markdown]
# # (B) : Plot The Result On SGD

# %%
n_epochs = [*range(epochs)]
plt.figure(figsize=(18,5))
plt.subplot(121)
plt.plot(n_epochs, log['train_loss'])
plt.plot(n_epochs, log['valid_loss'])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title('Loss SGD')
plt.legend(['train loss', 'valid loss'])
plt.subplot(122)
plt.plot(n_epochs, log['train_acc'])
plt.plot(n_epochs, log['valid_acc'])
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title('Accuracy SGD')
plt.legend(['train accuracy', 'valid accuracy'])

# %% [markdown]
# # (B) : Instatiate Model Class Base On Adam

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
model_adam = MyNet().to(device)

criterion = nn.CrossEntropyLoss()

lr_adam = 3e-4
epochs = 30
optimizer_adam = torch.optim.Adam(model_adam.parameters(), lr=lr_adam)

# %% [markdown]
# # (B) : Training Process Based On Adam

# %%
log = {'train_loss':[], 'valid_loss' : [], 'train_acc' : [], 'valid_acc' : []}
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    model_adam.train()
    train_loop(train_loader, model_adam, criterion, optimizer_adam, log)
    model_adam.eval()
    valid_loop(val_loader, model_adam, criterion, log)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Train Result:
#  Accuracy: 23.0%, Avg Train loss: 2.483481
#
# Validation Result:
#  Accuracy: 39.0%, Avg Validation loss: 1.819858
#
# Epoch 2
# -------------------------------
# Train Result:
#  Accuracy: 48.0%, Avg Train loss: 1.590184
#
# Validation Result:
#  Accuracy: 51.8%, Avg Validation loss: 1.418707
#
# Epoch 3
# -------------------------------
# Train Result:
#  Accuracy: 58.9%, Avg Train loss: 1.237977
#
# Validation Result:
#  Accuracy: 64.8%, Avg Validation loss: 1.060985
#
# Epoch 4
# -------------------------------
# Train Result:
#  Accuracy: 67.3%, Avg Train loss: 0.982316
#
# Validation Result:
#  Accuracy: 71.2%, Avg Validation loss: 0.870310
#
# Epoch 5
# -------------------------------
# Train Result:
#  Accuracy: 74.9%, Avg Train loss: 0.757903
#
# Validation Result:
#  Accuracy: 78.5%, Avg Validation loss: 0.652546
#
# Epoch 6
# -------------------------------
# Train Result:
#  Accuracy: 81.4%, Avg Train loss: 0.580777
#
# Validation Result:
#  Accuracy: 84.9%, Avg Validation loss: 0.474080
#
# Epoch 7
# -------------------------------
# Train Result:
#  Accuracy: 85.1%, Avg Train loss: 0.467292
#
# Validation Result:
#  Accuracy: 89.5%, Avg Validation loss: 0.374818
#
# Epoch 8
# -------------------------------
# Train Result:
#  Accuracy: 89.7%, Avg Train loss: 0.334973
#
# Validation Result:
#  Accuracy: 90.9%, Avg Validation loss: 0.307305
#
# Epoch 9
# -------------------------------
# Train Result:
#  Accuracy: 92.7%, Avg Train loss: 0.251637
#
# Validation Result:
#  Accuracy: 94.0%, Avg Validation loss: 0.208911
#
# Epoch 10
# -------------------------------
# Train Result:
#  Accuracy: 94.8%, Avg Train loss: 0.191481
#
# Validation Result:
#  Accuracy: 95.2%, Avg Validation loss: 0.178536
#
# Epoch 11
# -------------------------------
# Train Result:
#  Accuracy: 96.8%, Avg Train loss: 0.136913
#
# Validation Result:
#  Accuracy: 98.3%, Avg Validation loss: 0.099515
#
# Epoch 12
# -------------------------------
# Train Result:
#  Accuracy: 97.3%, Avg Train loss: 0.115360
#
# Validation Result:
#  Accuracy: 96.3%, Avg Validation loss: 0.125168
#
# Epoch 13
# -------------------------------
# Train Result:
#  Accuracy: 98.8%, Avg Train loss: 0.071434
#
# Validation Result:
#  Accuracy: 99.6%, Avg Validation loss: 0.046084
#
# Epoch 14
# -------------------------------
# Train Result:
#  Accuracy: 98.6%, Avg Train loss: 0.070376
#
# Validation Result:
#  Accuracy: 99.6%, Avg Validation loss: 0.039357
#
# Epoch 15
# -------------------------------
# Train Result:
#  Accuracy: 99.2%, Avg Train loss: 0.048783
#
# Validation Result:
#  Accuracy: 99.9%, Avg Validation loss: 0.027334
#
# Epoch 16
# -------------------------------
# Train Result:
#  Accuracy: 98.6%, Avg Train loss: 0.063001
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.019145
#
# Epoch 17
# -------------------------------
# Train Result:
#  Accuracy: 99.9%, Avg Train loss: 0.020236
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.014127
#
# Epoch 18
# -------------------------------
# Train Result:
#  Accuracy: 99.9%, Avg Train loss: 0.015531
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.014922
#
# Epoch 19
# -------------------------------
# Train Result:
#  Accuracy: 100.0%, Avg Train loss: 0.012623
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.010172
#
# Epoch 20
# -------------------------------
# Train Result:
#  Accuracy: 100.0%, Avg Train loss: 0.010045
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.008119
#
# Epoch 21
# -------------------------------
# Train Result:
#  Accuracy: 100.0%, Avg Train loss: 0.008583
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.005789
#
# Epoch 22
# -------------------------------
# Train Result:
#  Accuracy: 99.9%, Avg Train loss: 0.009694
#
# Validation Result:
#  Accuracy: 99.9%, Avg Validation loss: 0.011129
#
# Epoch 23
# -------------------------------
# Train Result:
#  Accuracy: 97.4%, Avg Train loss: 0.083449
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.010352
#
# Epoch 24
# -------------------------------
# Train Result:
#  Accuracy: 100.0%, Avg Train loss: 0.004981
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.004171
#
# Epoch 25
# -------------------------------
# Train Result:
#  Accuracy: 100.0%, Avg Train loss: 0.003966
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.003677
#
# Epoch 26
# -------------------------------
# Train Result:
#  Accuracy: 100.0%, Avg Train loss: 0.002879
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.002948
#
# Epoch 27
# -------------------------------
# Train Result:
#  Accuracy: 100.0%, Avg Train loss: 0.002439
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.002638
#
# Epoch 28
# -------------------------------
# Train Result:
#  Accuracy: 100.0%, Avg Train loss: 0.002248
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.002126
#
# Epoch 29
# -------------------------------
# Train Result:
#  Accuracy: 100.0%, Avg Train loss: 0.002245
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.001864
#
# Epoch 30
# -------------------------------
# Train Result:
#  Accuracy: 100.0%, Avg Train loss: 0.001647
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.001770
#
# Done!

# %% [markdown]
# # (B) : Plot The Result On Adam

# %%
n_epochs = [*range(epochs)]
plt.figure(figsize=(18,5))
plt.subplot(121)
plt.plot(n_epochs, log['train_loss'])
plt.plot(n_epochs, log['valid_loss'])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title('Loss Adam')
plt.legend(['train loss', 'valid loss'])
plt.subplot(122)
plt.plot(n_epochs, log['train_acc'])
plt.plot(n_epochs, log['valid_acc'])
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title('Accuracy Adam')
plt.legend(['train accuracy', 'valid accuracy'])

# %% [markdown]
# # (B) : Compare SGD & Adam On Test Data
#  Point : Using Adam make better result on test data

# %%
print('Model result on Adam optimizer:')
model_adam.eval()
test_loop(test_loader, model_adam, criterion)
print('Model result on SGD optimizer:')
model_sgd.eval()
test_loop(test_loader, model_sgd, criterion)
# Out:
# Model result on Adam optimizer:
# Test Result:
#  Accuracy: 78.2%, Avg Test loss: 1.463932
#
# Model result on SGD optimizer:
# Test Result:
#  Accuracy: 77.6%, Avg Test loss: 1.332979

# %% [markdown]
# # (C) : Create Model Class With Dropout

# %%
class DropoutNet(nn.Module):
    def __init__(self):
        super(DropoutNet, self).__init__()
        self.mlp = nn.Sequential(
            nn.Linear(28*28, 512),
            nn.ReLU(),
            nn.Linear(512, 1024),
            nn.ReLU(),
            nn.Dropout(p = 0.5),
            nn.Linear(1024, 512),
            nn.ReLU(),
            nn.Linear(512, 25)
        )

    def forward(self, x):
        logits = self.mlp(x)
        return logits

# %% [markdown]
# # (C) : Instatiate Dropout Model Class Base On SGD (Dropout)

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
model_sgd_drop = DropoutNet().to(device)

criterion = nn.CrossEntropyLoss()

lr_sgd = 0.01
epochs = 40
optimizer_sgd_drop = torch.optim.SGD(model_sgd_drop.parameters(), lr=lr_sgd, momentum=0.9)

# %% [markdown]
# # (C) : Training Process Based On SGD (Dropout Model)

# %%
log = {'train_loss':[], 'valid_loss' : [], 'train_acc' : [], 'valid_acc' : []}
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    model_sgd_drop.train()
    train_loop(train_loader, model_sgd_drop, criterion, optimizer_sgd_drop, log)
    model_sgd_drop.eval()
    valid_loop(val_loader, model_sgd_drop, criterion, log)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Train Result:
#  Accuracy: 6.6%, Avg Train loss: 3.160531
#
# Validation Result:
#  Accuracy: 12.5%, Avg Validation loss: 3.049669
#
# Epoch 2
# -------------------------------
# Train Result:
#  Accuracy: 20.7%, Avg Train loss: 2.523773
#
# Validation Result:
#  Accuracy: 33.3%, Avg Validation loss: 2.022345
#
# Epoch 3
# -------------------------------
# Train Result:
#  Accuracy: 39.5%, Avg Train loss: 1.817978
#
# Validation Result:
#  Accuracy: 50.4%, Avg Validation loss: 1.512326
#
# Epoch 4
# -------------------------------
# Train Result:
#  Accuracy: 53.4%, Avg Train loss: 1.381731
#
# Validation Result:
#  Accuracy: 58.6%, Avg Validation loss: 1.228282
#
# Epoch 5
# -------------------------------
# Train Result:
#  Accuracy: 62.2%, Avg Train loss: 1.109588
#
# Validation Result:
#  Accuracy: 69.7%, Avg Validation loss: 0.896853
#
# Epoch 6
# -------------------------------
# Train Result:
#  Accuracy: 66.8%, Avg Train loss: 0.961133
#
# Validation Result:
#  Accuracy: 77.2%, Avg Validation loss: 0.673536
#
# Epoch 7
# -------------------------------
# Train Result:
#  Accuracy: 74.0%, Avg Train loss: 0.755596
#
# Validation Result:
#  Accuracy: 77.3%, Avg Validation loss: 0.653275
#
# Epoch 8
# -------------------------------
# Train Result:
#  Accuracy: 76.7%, Avg Train loss: 0.675745
#
# Validation Result:
#  Accuracy: 85.7%, Avg Validation loss: 0.441955
#
# Epoch 9
# -------------------------------
# Train Result:
#  Accuracy: 82.5%, Avg Train loss: 0.515325
#
# Validation Result:
#  Accuracy: 89.8%, Avg Validation loss: 0.331523
#
# Epoch 10
# -------------------------------
# Train Result:
#  Accuracy: 84.4%, Avg Train loss: 0.449930
#
# Validation Result:
#  Accuracy: 87.3%, Avg Validation loss: 0.370741
#
# Epoch 11
# -------------------------------
# Train Result:
#  Accuracy: 89.0%, Avg Train loss: 0.326954
#
# Validation Result:
#  Accuracy: 94.6%, Avg Validation loss: 0.192511
#
# Epoch 12
# -------------------------------
# Train Result:
#  Accuracy: 91.8%, Avg Train loss: 0.246640
#
# Validation Result:
#  Accuracy: 90.5%, Avg Validation loss: 0.251343
#
# Epoch 13
# -------------------------------
# Train Result:
#  Accuracy: 91.7%, Avg Train loss: 0.244399
#
# Validation Result:
#  Accuracy: 96.1%, Avg Validation loss: 0.144042
#
# Epoch 14
# -------------------------------
# Train Result:
#  Accuracy: 94.0%, Avg Train loss: 0.186338
#
# Validation Result:
#  Accuracy: 94.1%, Avg Validation loss: 0.163107
#
# Epoch 15
# -------------------------------
# Train Result:
#  Accuracy: 95.6%, Avg Train loss: 0.142406
#
# Validation Result:
#  Accuracy: 97.6%, Avg Validation loss: 0.089932
#
# Epoch 16
# -------------------------------
# Train Result:
#  Accuracy: 96.3%, Avg Train loss: 0.122458
#
# Validation Result:
#  Accuracy: 96.5%, Avg Validation loss: 0.101930
#
# Epoch 17
# -------------------------------
# Train Result:
#  Accuracy: 96.2%, Avg Train loss: 0.117171
#
# Validation Result:
#  Accuracy: 99.3%, Avg Validation loss: 0.033751
#
# Epoch 18
# -------------------------------
# Train Result:
#  Accuracy: 97.5%, Avg Train loss: 0.084652
#
# Validation Result:
#  Accuracy: 96.4%, Avg Validation loss: 0.098647
#
# Epoch 19
# -------------------------------
# Train Result:
#  Accuracy: 98.3%, Avg Train loss: 0.066684
#
# Validation Result:
#  Accuracy: 99.6%, Avg Validation loss: 0.021959
#
# Epoch 20
# -------------------------------
# Train Result:
#  Accuracy: 97.7%, Avg Train loss: 0.081491
#
# Validation Result:
#  Accuracy: 99.7%, Avg Validation loss: 0.016876
#
# Epoch 21
# -------------------------------
# Train Result:
#  Accuracy: 99.0%, Avg Train loss: 0.041088
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.010489
#
# Epoch 22
# -------------------------------
# Train Result:
#  Accuracy: 98.9%, Avg Train loss: 0.039796
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.006949
#
# Epoch 23
# -------------------------------
# Train Result:
#  Accuracy: 99.8%, Avg Train loss: 0.016168
#
# Validation Result:
#  Accuracy: 99.9%, Avg Validation loss: 0.009157
#
# Epoch 24
# -------------------------------
# Train Result:
#  Accuracy: 98.6%, Avg Train loss: 0.048674
#
# Validation Result:
#  Accuracy: 99.9%, Avg Validation loss: 0.008637
#
# Epoch 25
# -------------------------------
# Train Result:
#  Accuracy: 99.5%, Avg Train loss: 0.021761
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.008373
#
# Epoch 26
# -------------------------------
# Train Result:
#  Accuracy: 99.9%, Avg Train loss: 0.010056
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.003268
#
# Epoch 27
# -------------------------------
# Train Result:
#  Accuracy: 99.9%, Avg Train loss: 0.010020
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.003449
#
# Epoch 28
# -------------------------------
# Train Result:
#  Accuracy: 98.5%, Avg Train loss: 0.048777
#
# Validation Result:
#  Accuracy: 97.0%, Avg Validation loss: 0.085075
#
# Epoch 29
# -------------------------------
# Train Result:
#  Accuracy: 98.9%, Avg Train loss: 0.038646
#
# Validation Result:
#  Accuracy: 99.7%, Avg Validation loss: 0.014111
#
# Epoch 30
# -------------------------------
# Train Result:
#  Accuracy: 99.4%, Avg Train loss: 0.022665
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.001607
#
# Epoch 31
# -------------------------------
# Train Result:
#  Accuracy: 99.9%, Avg Train loss: 0.007885
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.001580
#
# Epoch 32
# -------------------------------
# Train Result:
#  Accuracy: 99.9%, Avg Train loss: 0.006799
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.000913
#
# Epoch 33
# -------------------------------
# Train Result:
#  Accuracy: 99.9%, Avg Train loss: 0.006995
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.002347
#
# Epoch 34
# -------------------------------
# Train Result:
#  Accuracy: 99.6%, Avg Train loss: 0.016856
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.001278
#
# Epoch 35
# -------------------------------
# Train Result:
#  Accuracy: 99.8%, Avg Train loss: 0.009812
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.002039
#
# Epoch 36
# -------------------------------
# Train Result:
#  Accuracy: 99.9%, Avg Train loss: 0.006345
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.001762
#
# Epoch 37
# -------------------------------
# Train Result:
#  Accuracy: 99.9%, Avg Train loss: 0.006428
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.000710
#
# Epoch 38
# -------------------------------
# Train Result:
#  Accuracy: 99.9%, Avg Train loss: 0.004779
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.001609
#
# Epoch 39
# -------------------------------
# Train Result:
#  Accuracy: 99.9%, Avg Train loss: 0.005309
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.000601
#
# Epoch 40
# -------------------------------
# Train Result:
#  Accuracy: 100.0%, Avg Train loss: 0.003983
#
# Validation Result:
#  Accuracy: 99.8%, Avg Validation loss: 0.006448
#
# Done!

# %%
print('Dropout model result on SGD optimizer:')
model_sgd_drop.eval()
test_loop(test_loader, model_sgd_drop, criterion)
# Out:
# Dropout model result on SGD optimizer:
# Test Result:
#  Accuracy: 78.4%, Avg Test loss: 1.351311

# %% [markdown]
# # (C) : Plot The Result On SGD (Dropout Model)

# %%
n_epochs = [*range(epochs)]
plt.figure(figsize=(18,5))
plt.subplot(121)
plt.plot(n_epochs, log['train_loss'])
plt.plot(n_epochs, log['valid_loss'])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title('Loss SGD')
plt.legend(['train loss', 'valid loss'])
plt.subplot(122)
plt.plot(n_epochs, log['train_acc'])
plt.plot(n_epochs, log['valid_acc'])
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title('Accuracy SGD')
plt.legend(['train accuracy', 'valid accuracy'])

# %% [markdown]
# # (C) : Instatiate Model Class Base On Adam (Dropout Model)

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
model_adam_drop = DropoutNet().to(device)

criterion = nn.CrossEntropyLoss()

lr_adam = 3e-4
epochs = 40
optimizer_adam_drop = torch.optim.Adam(model_adam_drop.parameters(), lr=lr_adam)

# %% [markdown]
# # (C) : Training Process Based On Adam (Dropout Model)

# %%
log = {'train_loss':[], 'valid_loss' : [], 'train_acc' : [], 'valid_acc' : []}
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    model_adam_drop.train()
    train_loop(train_loader, model_adam_drop, criterion, optimizer_adam_drop, log)
    model_adam_drop.eval()
    valid_loop(val_loader, model_adam_drop, criterion, log)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Train Result:
#  Accuracy: 20.2%, Avg Train loss: 2.572759
#
# Validation Result:
#  Accuracy: 41.4%, Avg Validation loss: 1.826330
#
# Epoch 2
# -------------------------------
# Train Result:
#  Accuracy: 47.2%, Avg Train loss: 1.597981
#
# Validation Result:
#  Accuracy: 61.2%, Avg Validation loss: 1.226167
#
# Epoch 3
# -------------------------------
# Train Result:
#  Accuracy: 60.2%, Avg Train loss: 1.166535
#
# Validation Result:
#  Accuracy: 70.7%, Avg Validation loss: 0.920558
#
# Epoch 4
# -------------------------------
# Train Result:
#  Accuracy: 69.7%, Avg Train loss: 0.894868
#
# Validation Result:
#  Accuracy: 80.3%, Avg Validation loss: 0.646426
#
# Epoch 5
# -------------------------------
# Train Result:
#  Accuracy: 77.1%, Avg Train loss: 0.682383
#
# Validation Result:
#  Accuracy: 84.9%, Avg Validation loss: 0.497202
#
# Epoch 6
# -------------------------------
# Train Result:
#  Accuracy: 82.9%, Avg Train loss: 0.514279
#
# Validation Result:
#  Accuracy: 88.2%, Avg Validation loss: 0.385397
#
# Epoch 7
# -------------------------------
# Train Result:
#  Accuracy: 86.6%, Avg Train loss: 0.397806
#
# Validation Result:
#  Accuracy: 92.5%, Avg Validation loss: 0.253016
#
# Epoch 8
# -------------------------------
# Train Result:
#  Accuracy: 89.2%, Avg Train loss: 0.332343
#
# Validation Result:
#  Accuracy: 92.4%, Avg Validation loss: 0.253974
#
# Epoch 9
# -------------------------------
# Train Result:
#  Accuracy: 92.1%, Avg Train loss: 0.249186
#
# Validation Result:
#  Accuracy: 96.1%, Avg Validation loss: 0.163044
#
# Epoch 10
# -------------------------------
# Train Result:
#  Accuracy: 93.7%, Avg Train loss: 0.198546
#
# Validation Result:
#  Accuracy: 98.1%, Avg Validation loss: 0.099656
#
# Epoch 11
# -------------------------------
# Train Result:
#  Accuracy: 94.5%, Avg Train loss: 0.173663
#
# Validation Result:
#  Accuracy: 97.6%, Avg Validation loss: 0.102347
#
# Epoch 12
# -------------------------------
# Train Result:
#  Accuracy: 96.5%, Avg Train loss: 0.125052
#
# Validation Result:
#  Accuracy: 98.8%, Avg Validation loss: 0.065024
#
# Epoch 13
# -------------------------------
# Train Result:
#  Accuracy: 97.5%, Avg Train loss: 0.095945
#
# Validation Result:
#  Accuracy: 99.2%, Avg Validation loss: 0.047734
#
# Epoch 14
# -------------------------------
# Train Result:
#  Accuracy: 98.2%, Avg Train loss: 0.074442
#
# Validation Result:
#  Accuracy: 99.4%, Avg Validation loss: 0.035777
#
# Epoch 15
# -------------------------------
# Train Result:
#  Accuracy: 97.6%, Avg Train loss: 0.086620
#
# Validation Result:
#  Accuracy: 98.7%, Avg Validation loss: 0.053708
#
# Epoch 16
# -------------------------------
# Train Result:
#  Accuracy: 98.2%, Avg Train loss: 0.064862
#
# Validation Result:
#  Accuracy: 99.4%, Avg Validation loss: 0.032137
#
# Epoch 17
# -------------------------------
# Train Result:
#  Accuracy: 97.8%, Avg Train loss: 0.079060
#
# Validation Result:
#  Accuracy: 99.9%, Avg Validation loss: 0.015491
#
# Epoch 18
# -------------------------------
# Train Result:
#  Accuracy: 98.8%, Avg Train loss: 0.047591
#
# Validation Result:
#  Accuracy: 99.8%, Avg Validation loss: 0.018363
#
# Epoch 19
# -------------------------------
# Train Result:
#  Accuracy: 99.2%, Avg Train loss: 0.037354
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.007833
#
# Epoch 20
# -------------------------------
# Train Result:
#  Accuracy: 99.2%, Avg Train loss: 0.034006
#
# Validation Result:
#  Accuracy: 99.9%, Avg Validation loss: 0.011509
#
# Epoch 21
# -------------------------------
# Train Result:
#  Accuracy: 98.5%, Avg Train loss: 0.050496
#
# Validation Result:
#  Accuracy: 93.6%, Avg Validation loss: 0.185190
#
# Epoch 22
# -------------------------------
# Train Result:
#  Accuracy: 98.2%, Avg Train loss: 0.059437
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.005421
#
# Epoch 23
# -------------------------------
# Train Result:
#  Accuracy: 99.2%, Avg Train loss: 0.029430
#
# Validation Result:
#  Accuracy: 99.8%, Avg Validation loss: 0.011919
#
# Epoch 24
# -------------------------------
# Train Result:
#  Accuracy: 99.2%, Avg Train loss: 0.027618
#
# Validation Result:
#  Accuracy: 99.9%, Avg Validation loss: 0.005848
#
# Epoch 25
# -------------------------------
# Train Result:
#  Accuracy: 99.7%, Avg Train loss: 0.015107
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.004151
#
# Epoch 26
# -------------------------------
# Train Result:
#  Accuracy: 98.7%, Avg Train loss: 0.043729
#
# Validation Result:
#  Accuracy: 98.9%, Avg Validation loss: 0.033702
#
# Epoch 27
# -------------------------------
# Train Result:
#  Accuracy: 98.9%, Avg Train loss: 0.036355
#
# Validation Result:
#  Accuracy: 99.4%, Avg Validation loss: 0.020616
#
# Epoch 28
# -------------------------------
# Train Result:
#  Accuracy: 99.6%, Avg Train loss: 0.016834
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.003730
#
# Epoch 29
# -------------------------------
# Train Result:
#  Accuracy: 98.8%, Avg Train loss: 0.037159
#
# Validation Result:
#  Accuracy: 99.9%, Avg Validation loss: 0.006617
#
# Epoch 30
# -------------------------------
# Train Result:
#  Accuracy: 99.5%, Avg Train loss: 0.017863
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.002322
#
# Epoch 31
# -------------------------------
# Train Result:
#  Accuracy: 99.0%, Avg Train loss: 0.033204
#
# Validation Result:
#  Accuracy: 99.9%, Avg Validation loss: 0.008471
#
# Epoch 32
# -------------------------------
# Train Result:
#  Accuracy: 98.7%, Avg Train loss: 0.041097
#
# Validation Result:
#  Accuracy: 98.9%, Avg Validation loss: 0.032876
#
# Epoch 33
# -------------------------------
# Train Result:
#  Accuracy: 99.4%, Avg Train loss: 0.021368
#
# Validation Result:
#  Accuracy: 99.0%, Avg Validation loss: 0.034696
#
# Epoch 34
# -------------------------------
# Train Result:
#  Accuracy: 99.6%, Avg Train loss: 0.014416
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.001027
#
# Epoch 35
# -------------------------------
# Train Result:
#  Accuracy: 99.7%, Avg Train loss: 0.010671
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.000780
#
# Epoch 36
# -------------------------------
# Train Result:
#  Accuracy: 96.8%, Avg Train loss: 0.111919
#
# Validation Result:
#  Accuracy: 99.4%, Avg Validation loss: 0.029443
#
# Epoch 37
# -------------------------------
# Train Result:
#  Accuracy: 99.7%, Avg Train loss: 0.014057
#
# Validation Result:
#  Accuracy: 99.9%, Avg Validation loss: 0.004854
#
# Epoch 38
# -------------------------------
# Train Result:
#  Accuracy: 100.0%, Avg Train loss: 0.005205
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.000893
#
# Epoch 39
# -------------------------------
# Train Result:
#  Accuracy: 100.0%, Avg Train loss: 0.003978
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.000559
#
# Epoch 40
# -------------------------------
# Train Result:
#  Accuracy: 99.8%, Avg Train loss: 0.009991
#
# Validation Result:
#  Accuracy: 100.0%, Avg Validation loss: 0.001642
#
# Done!

# %% [markdown]
# # (C) : Plot The Result On Adam (Dropout Model)

# %%
n_epochs = [*range(epochs)]
plt.figure(figsize=(18,5))
plt.subplot(121)
plt.plot(n_epochs, log['train_loss'])
plt.plot(n_epochs, log['valid_loss'])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title('Loss Adam Dropout')
plt.legend(['train loss', 'valid loss'])
plt.subplot(122)
plt.plot(n_epochs, log['train_acc'])
plt.plot(n_epochs, log['valid_acc'])
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title('Accuracy Adam Dropout')
plt.legend(['train accuracy', 'valid accuracy'])

# %% [markdown]
# # (C) : Compare SGD & Adam On Test Data (Dropout Model)

# %%
print('Dropout model result on Adam optimizer:')
model_adam_drop.eval()
test_loop(test_loader, model_adam_drop, criterion)
print('Dropout model result on SGD optimizer:')
model_sgd_drop.eval()
test_loop(test_loader, model_sgd_drop, criterion)
# Out:
# Dropout model result on Adam optimizer:
# Test Result:
#  Accuracy: 81.6%, Avg Test loss: 0.999835
#
# Dropout model result on SGD optimizer:
# Test Result:
#  Accuracy: 78.4%, Avg Test loss: 1.392899

# %% [markdown]
# # (D) : All Trained Model Specification And Result (Dropout Model)
#  Point1 : Using dropout decrease test error because it helps to generalization.
#
#  Point2 : Using dropout has better result on Adam Optimizer and better generalize
#
#  Point3 : Adding Dropout to Adam increased accuracy to 82%

# %%
print('Model With 3 layer Mlp on Adam optimizer:')
model_adam.eval()
test_loop(test_loader, model_adam, criterion)
print('Model With 3 layer Mlp on Adam optimizer:')
model_sgd.eval()
test_loop(test_loader, model_sgd, criterion)
print('Model With 3 layer Mlp and One layer Dropout (P = 0.5) on Adam optimizer:')
model_adam_drop.eval()
test_loop(test_loader, model_adam_drop, criterion)
print('Model With 3 layer Mlp and One layer Dropout (P = 0.5) on SGD optimizer:')
model_sgd_drop.eval()
test_loop(test_loader, model_sgd_drop, criterion)
# Out:
# Model With 3 layer Mlp on Adam optimizer:
# Test Result:
#  Accuracy: 78.2%, Avg Test loss: 1.552572
#
# Model With 3 layer Mlp on Adam optimizer:
# Test Result:
#  Accuracy: 77.6%, Avg Test loss: 1.292424
#
# Model With 3 layer Mlp and One layer Dropout (P = 0.5) on Adam optimizer:
# Test Result:
#  Accuracy: 81.6%, Avg Test loss: 0.994619
#
# Model With 3 layer Mlp and One layer Dropout (P = 0.5) on SGD optimizer:
# Test Result:
#  Accuracy: 78.4%, Avg Test loss: 1.368604

# %% [markdown]
# # (E) : Test Base On Webcam (Dropout Model)

# %%
import torchvision.transforms as T
import torchvision.transforms as transforms

list_image = ['CamScanner 12-21-2022 20.24_1.jpg', 'CamScanner 12-21-2022 20.27_1.jpg',
              'CamScanner 12-21-2022 20.29_1.jpg','CamScanner 12-21-2022 20.30_1.jpg']

figure = plt.figure(figsize=(40, 40))

transform1 = transforms.Grayscale()
transform2 = T.Resize(size = (300,300))
j = 1

for i in list_image :
    image = read_image(i)
    figure.add_subplot(2, 2, j)
    plt.axis("off")
    plt.imshow(image[0,::], cmap="gray") 
    j +=1
plt.show()

# %%
list_image = ['CamScanner 12-21-2022 20.24_1.jpg', 'CamScanner 12-21-2022 20.27_1.jpg',
              'CamScanner 12-21-2022 20.29_1.jpg','CamScanner 12-21-2022 20.30_1.jpg']

True_label = [1,2,8,12]

figure = plt.figure(figsize=(10, 10))

transform1 = transforms.Grayscale()
transform2 = T.Resize(size = (28,28))
j = 1
model_adam_drop.eval()
for i in list_image :
    image = read_image(i)
    img_resized = transform2(image)
    with torch.no_grad():
        img = (img_resized[0,:,:]/255.).view(1, -1)
        pred = model_adam_drop(img.to(torch.float32).to(device))
        
        figure.add_subplot(2, 2, j)
        plt.title(f"Label: {True_label[j-1]}   Predicted: {pred.argmax().item()}")
        plt.axis("off")
        plt.imshow(img_resized[0,:,:], cmap="gray")
        j += 1
        
plt.show()
