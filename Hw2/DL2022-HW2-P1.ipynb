# %% [markdown]
# # Import Packages

# %%
import torch
import torch.nn as nn
import torchvision.transforms as transforms
import torchvision.datasets as dsets
from torch.autograd import Variable
from tqdm import tqdm_notebook
import numpy as np
import random
import matplotlib.pyplot as plt

# %% [markdown]
# # (A) : Loading Dataset

# %%
train_dataset = dsets.FashionMNIST(root='./data',
                                  train=True,
                                  transform=transforms.ToTensor(),
                                  download=True,
                                  target_transform = transforms.Lambda(lambda y: torch.zeros(10, dtype=torch.float).scatter_(dim=0, index=torch.tensor(y),
                                                                                    value=1)))

test_dataset = dsets.FashionMNIST(root='./data',
                                  train=False,
                                  transform=transforms.ToTensor(),
                                  download=True,
                                  target_transform = transforms.Lambda(lambda y: torch.zeros(10, dtype=torch.float).scatter_(dim=0, index=torch.tensor(y),
                                                                                    value=1)))

train_dataset, valid_dataset = torch.utils.data.random_split(train_dataset,(int(len(train_dataset) * 0.8), len(train_dataset) - int(len(train_dataset) * 0.8)))

# %% [markdown]
# # (A) : Showing Some Sample From Dataset

# %%
# Choosing one data and visualizing it
print(f"Shape of the images: {train_dataset[0][0].shape}")

Class_Name = { 0: "T-Shirt", 1: "Trouser", 2: "Pullover", 3: "Dress", 4: "Coat", 5: "Sandal", 6: "Shirt", 7: "Sneaker", 8: "Bag", 9: "Ankle Boot"}
figure = plt.figure(figsize=(15, 15))
k = 0
label_list = []
while len(label_list) != 10:
    index = random.randint(0, len(train_dataset)-1)
    img, label = train_dataset[index]
    label = int(torch.argmax(label).numpy())
    if label not in label_list:
        k += 1
        label_list.append(label)
        figure.add_subplot(4, 5, k)
        plt.title(Class_Name[label])
        plt.axis("off")
        plt.imshow(img.squeeze(), cmap="gray")  
    
plt.show()
# Out:
# Shape of the images: torch.Size([1, 28, 28])

# %% [markdown]
# # (B) : Making Dataset Iterable

# %%
batch_size = 128

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=batch_size, 
                                           shuffle=True)

valid_loader = torch.utils.data.DataLoader(dataset=valid_dataset, 
                                          batch_size=batch_size, 
                                          shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset, 
                                          batch_size=batch_size, 
                                          shuffle=True)

# %% [markdown]
# # (B) : Activation Functions

# %%
def tanh(x):
    y = (torch.exp(x) - torch.exp(-1 * x)) / (torch.exp(x) + torch.exp(-1 * x))
    return y

def softmax(x):
    x_exp = torch.exp(x)
    partition = x_exp.sum(1, keepdims=True)
    return x_exp / partition

def ReLU(x):
    k = torch.zeros_like(x)
    y = torch.maximum(x, k)
    return y

# %% [markdown]
# # (B) : Initialize Model parameter and Create model

# %%
w1 = torch.randn(784, 256, requires_grad=True)
b1 = torch.randn(1, 256, requires_grad=True)

w2 = torch.randn(256, 128, requires_grad=True)
b2 = torch.randn(1, 128, requires_grad=True)

w3 = torch.randn(128, 64, requires_grad=True)
b3 = torch.randn(1, 64, requires_grad=True)

w4 = torch.randn(64, 10, requires_grad=True)
b4 = torch.randn(1, 10, requires_grad=True)

# %%
def model(xb):
    global w1, b1, w2, b2, w3, b3, w4, b4
    
    y1 = torch.matmul(xb, w1) + b1
    y1 = tanh(y1)

    y2 = torch.matmul(y1, w2) + b2
    y2 = tanh(y2)

    y3 = torch.matmul(y2, w3) + b3
    y3 = tanh(y3)

    y4 = torch.matmul(y3, w4) + b4
    y4 = tanh(y4)

    yb = softmax(y4)
    return yb

# %% [markdown]
# # (C) : Create Loss Function

# %%
def BinaryCrossEntropy(y_hat, y):
    r =  (-1 / batch_size) * torch.sum(y * torch.log(y_hat) + (1 - y) * torch.log(1 - y_hat))
    return r

# %% [markdown]
# # (C) : Define Hyper Parameter

# %%
learning_rate = 1e-1
epochs = 100

# %% [markdown]
# # (C) : Define Train & Test Loop

# %%
def train_loop(dataloader, model, loss_fn, log):
    global w1, b1, w2, b2, w3, b3, w4, b4
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    train_loss, train_acc = 0, 0
    for batch, (x, y) in enumerate(dataloader):
        x = x.view(x.shape[0], -1)
        pred = model(x)
        loss = loss_fn(pred, y)
        loss.backward()
        with torch.no_grad():
            w1 -= learning_rate * w1.grad
            b1 -= learning_rate * b1.grad
            w2 -= learning_rate * w2.grad
            b2 -= learning_rate * b2.grad
            w3 -= learning_rate * w3.grad
            b3 -= learning_rate * b3.grad
            w4 -= learning_rate * w4.grad
            b4 -= learning_rate * b4.grad
            w1.grad.zero_()
            b1.grad.zero_()
            w2.grad.zero_()
            b2.grad.zero_()
            w3.grad.zero_()
            b3.grad.zero_()
            w4.grad.zero_()
            b4.grad.zero_()
            
        train_loss += loss.item()
        train_acc += (pred.argmax(1) == y.argmax(1)).type(torch.float).sum().item()
            
    train_loss /= num_batches
    train_acc /= size

    log['train_loss'].append(train_loss)
    log['train_acc'].append(train_acc)
    print(f"Train Result: \n Accuracy: {(100*train_acc):>0.1f}%, Avg Train loss: {train_loss:>8f} \n")
    
    
def valid_loop(dataloader, model, loss_fn, log):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    valid_loss, valid_acc = 0, 0
    with torch.no_grad():
        for x, y in dataloader:
            x = x.view(x.shape[0], -1)
            pred = model(x)
            valid_loss += loss_fn(pred, y).item()
            valid_acc += (pred.argmax(1) == y.argmax(1)).type(torch.float).sum().item()

    valid_loss /= num_batches
    valid_acc /= size
    
    log['valid_loss'].append(valid_loss)
    log['valid_acc'].append(valid_acc)
    print(f"Validation Result: \n Accuracy: {(100*valid_acc):>0.1f}%, Avg Validation loss: {valid_loss:>8f} \n")


def test_loop(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, test_acc = 0, 0

    with torch.no_grad():
        for x, y in dataloader:
            x = x.view(x.shape[0], -1)
            pred = model(x)
            test_loss += loss_fn(pred, y).item()
            test_acc += (pred.argmax(1) == y.argmax(1)).type(torch.float).sum().item()

    test_loss /= num_batches
    test_acc /= size
    print(f"Test Result: \n Accuracy: {(100*test_acc):>0.1f}%, Avg Test loss: {test_loss:>8f} \n")

# %% [markdown]
# # (C) : Training Process

# %%
log = {'train_loss':[], 'valid_loss' : [], 'train_acc' : [], 'valid_acc' : []}
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train_loop(train_loader, model, loss_fn = BinaryCrossEntropy, log = log)
    valid_loop(valid_loader, model, loss_fn = BinaryCrossEntropy, log = log)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Train Result:
#  Accuracy: 26.0%, Avg Train loss: 3.045340
#
# Validation Result:
#  Accuracy: 38.3%, Avg Validation loss: 2.697116
#
# Epoch 2
# -------------------------------
# Train Result:
#  Accuracy: 43.7%, Avg Train loss: 2.513378
#
# Validation Result:
#  Accuracy: 48.6%, Avg Validation loss: 2.351732
#
# Epoch 3
# -------------------------------
# Train Result:
#  Accuracy: 52.2%, Avg Train loss: 2.279683
#
# Validation Result:
#  Accuracy: 54.5%, Avg Validation loss: 2.224799
#
# Epoch 4
# -------------------------------
# Train Result:
#  Accuracy: 56.6%, Avg Train loss: 2.176267
#
# Validation Result:
#  Accuracy: 57.4%, Avg Validation loss: 2.156430
#
# Epoch 5
# -------------------------------
# Train Result:
#  Accuracy: 59.4%, Avg Train loss: 2.113694
#
# Validation Result:
#  Accuracy: 60.7%, Avg Validation loss: 2.085773
#
# Epoch 6
# -------------------------------
# Train Result:
#  Accuracy: 61.1%, Avg Train loss: 2.074428
#
# Validation Result:
#  Accuracy: 61.4%, Avg Validation loss: 2.052982
#
# Epoch 7
# -------------------------------
# Train Result:
#  Accuracy: 62.0%, Avg Train loss: 2.043761
#
# Validation Result:
#  Accuracy: 62.4%, Avg Validation loss: 2.038405
#
# Epoch 8
# -------------------------------
# Train Result:
#  Accuracy: 62.9%, Avg Train loss: 2.022859
#
# Validation Result:
#  Accuracy: 63.0%, Avg Validation loss: 2.008258
#
# Epoch 9
# -------------------------------
# Train Result:
#  Accuracy: 63.6%, Avg Train loss: 1.995889
#
# Validation Result:
#  Accuracy: 63.9%, Avg Validation loss: 1.994329
#
# Epoch 10
# -------------------------------
# Train Result:
#  Accuracy: 64.4%, Avg Train loss: 1.981042
#
# Validation Result:
#  Accuracy: 64.0%, Avg Validation loss: 1.974908
#
# Epoch 11
# -------------------------------
# Train Result:
#  Accuracy: 64.1%, Avg Train loss: 1.975749
#
# Validation Result:
#  Accuracy: 63.2%, Avg Validation loss: 1.985444
#
# Epoch 12
# -------------------------------
# Train Result:
#  Accuracy: 64.3%, Avg Train loss: 1.967325
#
# Validation Result:
#  Accuracy: 64.4%, Avg Validation loss: 1.968579
#
# Epoch 13
# -------------------------------
# Train Result:
#  Accuracy: 65.5%, Avg Train loss: 1.951673
#
# Validation Result:
#  Accuracy: 65.1%, Avg Validation loss: 1.952166
#
# Epoch 14
# -------------------------------
# Train Result:
#  Accuracy: 65.7%, Avg Train loss: 1.938787
#
# Validation Result:
#  Accuracy: 64.2%, Avg Validation loss: 1.951193
#
# Epoch 15
# -------------------------------
# Train Result:
#  Accuracy: 65.5%, Avg Train loss: 1.936374
#
# Validation Result:
#  Accuracy: 65.5%, Avg Validation loss: 1.949978
#
# Epoch 16
# -------------------------------
# Train Result:
#  Accuracy: 66.4%, Avg Train loss: 1.929050
#
# Validation Result:
#  Accuracy: 65.8%, Avg Validation loss: 1.936367
#
# Epoch 17
# -------------------------------
# Train Result:
#  Accuracy: 66.9%, Avg Train loss: 1.919332
#
# Validation Result:
#  Accuracy: 66.3%, Avg Validation loss: 1.926439
#
# Epoch 18
# -------------------------------
# Train Result:
#  Accuracy: 67.1%, Avg Train loss: 1.910255
#
# Validation Result:
#  Accuracy: 66.4%, Avg Validation loss: 1.920715
#
# Epoch 19
# -------------------------------
# Train Result:
#  Accuracy: 67.4%, Avg Train loss: 1.907135
#
# Validation Result:
#  Accuracy: 67.0%, Avg Validation loss: 1.911305
#
# Epoch 20
# -------------------------------
# Train Result:
#  Accuracy: 67.6%, Avg Train loss: 1.898579
#
# Validation Result:
#  Accuracy: 67.2%, Avg Validation loss: 1.910254
#
# Epoch 21
# -------------------------------
# Train Result:
#  Accuracy: 68.1%, Avg Train loss: 1.896090
#
# Validation Result:
#  Accuracy: 67.0%, Avg Validation loss: 1.910520
#
# Epoch 22
# -------------------------------
# Train Result:
#  Accuracy: 69.5%, Avg Train loss: 1.889963
#
# Validation Result:
#  Accuracy: 67.8%, Avg Validation loss: 1.904966
#
# Epoch 23
# -------------------------------
# Train Result:
#  Accuracy: 69.7%, Avg Train loss: 1.884377
#
# Validation Result:
#  Accuracy: 69.0%, Avg Validation loss: 1.893572
#
# Epoch 24
# -------------------------------
# Train Result:
#  Accuracy: 69.9%, Avg Train loss: 1.879808
#
# Validation Result:
#  Accuracy: 69.7%, Avg Validation loss: 1.891793
#
# Epoch 25
# -------------------------------
# Train Result:
#  Accuracy: 70.5%, Avg Train loss: 1.878969
#
# Validation Result:
#  Accuracy: 70.1%, Avg Validation loss: 1.886075
#
# Epoch 26
# -------------------------------
# Train Result:
#  Accuracy: 72.4%, Avg Train loss: 1.865045
#
# Validation Result:
#  Accuracy: 72.1%, Avg Validation loss: 1.870665
#
# Epoch 27
# -------------------------------
# Train Result:
#  Accuracy: 73.4%, Avg Train loss: 1.853392
#
# Validation Result:
#  Accuracy: 73.5%, Avg Validation loss: 1.866670
#
# Epoch 28
# -------------------------------
# Train Result:
#  Accuracy: 74.8%, Avg Train loss: 1.846437
#
# Validation Result:
#  Accuracy: 73.9%, Avg Validation loss: 1.861737
#
# Epoch 29
# -------------------------------
# Train Result:
#  Accuracy: 75.4%, Avg Train loss: 1.838700
#
# Validation Result:
#  Accuracy: 74.7%, Avg Validation loss: 1.850766
#
# Epoch 30
# -------------------------------
# Train Result:
#  Accuracy: 75.7%, Avg Train loss: 1.828413
#
# Validation Result:
#  Accuracy: 75.2%, Avg Validation loss: 1.842252
#
# Epoch 31
# -------------------------------
# Train Result:
#  Accuracy: 76.1%, Avg Train loss: 1.824879
#
# Validation Result:
#  Accuracy: 75.2%, Avg Validation loss: 1.843575
#
# Epoch 32
# -------------------------------
# Train Result:
#  Accuracy: 76.5%, Avg Train loss: 1.816900
#
# Validation Result:
#  Accuracy: 75.6%, Avg Validation loss: 1.835672
#
# Epoch 33
# -------------------------------
# Train Result:
#  Accuracy: 76.9%, Avg Train loss: 1.809590
#
# Validation Result:
#  Accuracy: 75.7%, Avg Validation loss: 1.833622
#
# Epoch 34
# -------------------------------
# Train Result:
#  Accuracy: 76.9%, Avg Train loss: 1.805724
#
# Validation Result:
#  Accuracy: 75.9%, Avg Validation loss: 1.826590
#
# Epoch 35
# -------------------------------
# Train Result:
#  Accuracy: 77.2%, Avg Train loss: 1.802579
#
# Validation Result:
#  Accuracy: 76.0%, Avg Validation loss: 1.819505
#
# Epoch 36
# -------------------------------
# Train Result:
#  Accuracy: 77.5%, Avg Train loss: 1.799113
#
# Validation Result:
#  Accuracy: 75.9%, Avg Validation loss: 1.818508
#
# Epoch 37
# -------------------------------
# Train Result:
#  Accuracy: 77.5%, Avg Train loss: 1.794244
#
# Validation Result:
#  Accuracy: 76.1%, Avg Validation loss: 1.813828
#
# Epoch 38
# -------------------------------
# Train Result:
#  Accuracy: 77.6%, Avg Train loss: 1.789287
#
# Validation Result:
#  Accuracy: 76.7%, Avg Validation loss: 1.808050
#
# Epoch 39
# -------------------------------
# Train Result:
#  Accuracy: 77.8%, Avg Train loss: 1.788520
#
# Validation Result:
#  Accuracy: 77.0%, Avg Validation loss: 1.808006
#
# Epoch 40
# -------------------------------
# Train Result:
#  Accuracy: 78.2%, Avg Train loss: 1.784762
#
# Validation Result:
#  Accuracy: 76.7%, Avg Validation loss: 1.805460
#
# Epoch 41
# -------------------------------
# Train Result:
#  Accuracy: 78.1%, Avg Train loss: 1.784687
#
# Validation Result:
#  Accuracy: 77.0%, Avg Validation loss: 1.807417
#
# Epoch 42
# -------------------------------
# Train Result:
#  Accuracy: 78.2%, Avg Train loss: 1.785653
#
# Validation Result:
#  Accuracy: 77.3%, Avg Validation loss: 1.801696
#
# Epoch 43
# -------------------------------
# Train Result:
#  Accuracy: 78.3%, Avg Train loss: 1.780244
#
# Validation Result:
#  Accuracy: 77.9%, Avg Validation loss: 1.793763
#
# Epoch 44
# -------------------------------
# Train Result:
#  Accuracy: 78.5%, Avg Train loss: 1.773676
#
# Validation Result:
#  Accuracy: 78.0%, Avg Validation loss: 1.793491
#
# Epoch 45
# -------------------------------
# Train Result:
#  Accuracy: 78.9%, Avg Train loss: 1.772600
#
# Validation Result:
#  Accuracy: 77.7%, Avg Validation loss: 1.789785
#
# Epoch 46
# -------------------------------
# Train Result:
#  Accuracy: 79.1%, Avg Train loss: 1.765452
#
# Validation Result:
#  Accuracy: 78.2%, Avg Validation loss: 1.787673
#
# Epoch 47
# -------------------------------
# Train Result:
#  Accuracy: 79.2%, Avg Train loss: 1.767517
#
# Validation Result:
#  Accuracy: 78.1%, Avg Validation loss: 1.794350
#
# Epoch 48
# -------------------------------
# Train Result:
#  Accuracy: 79.4%, Avg Train loss: 1.762906
#
# Validation Result:
#  Accuracy: 78.1%, Avg Validation loss: 1.790241
#
# Epoch 49
# -------------------------------
# Train Result:
#  Accuracy: 79.6%, Avg Train loss: 1.758141
#
# Validation Result:
#  Accuracy: 78.7%, Avg Validation loss: 1.779154
#
# Epoch 50
# -------------------------------
# Train Result:
#  Accuracy: 79.5%, Avg Train loss: 1.757447
#
# Validation Result:
#  Accuracy: 78.5%, Avg Validation loss: 1.784920
#
# Epoch 51
# -------------------------------
# Train Result:
#  Accuracy: 79.7%, Avg Train loss: 1.752694
#
# Validation Result:
#  Accuracy: 78.6%, Avg Validation loss: 1.781930
#
# Epoch 52
# -------------------------------
# Train Result:
#  Accuracy: 79.7%, Avg Train loss: 1.752213
#
# Validation Result:
#  Accuracy: 79.0%, Avg Validation loss: 1.780765
#
# Epoch 53
# -------------------------------
# Train Result:
#  Accuracy: 80.0%, Avg Train loss: 1.744657
#
# Validation Result:
#  Accuracy: 78.7%, Avg Validation loss: 1.775918
#
# Epoch 54
# -------------------------------
# Train Result:
#  Accuracy: 80.2%, Avg Train loss: 1.742127
#
# Validation Result:
#  Accuracy: 79.0%, Avg Validation loss: 1.772772
#
# Epoch 55
# -------------------------------
# Train Result:
#  Accuracy: 80.3%, Avg Train loss: 1.741990
#
# Validation Result:
#  Accuracy: 79.1%, Avg Validation loss: 1.768838
#
# Epoch 56
# -------------------------------
# Train Result:
#  Accuracy: 80.3%, Avg Train loss: 1.739188
#
# Validation Result:
#  Accuracy: 79.4%, Avg Validation loss: 1.768073
#
# Epoch 57
# -------------------------------
# Train Result:
#  Accuracy: 80.6%, Avg Train loss: 1.735142
#
# Validation Result:
#  Accuracy: 79.2%, Avg Validation loss: 1.767834
#
# Epoch 58
# -------------------------------
# Train Result:
#  Accuracy: 80.5%, Avg Train loss: 1.732081
#
# Validation Result:
#  Accuracy: 78.7%, Avg Validation loss: 1.767052
#
# Epoch 59
# -------------------------------
# Train Result:
#  Accuracy: 80.5%, Avg Train loss: 1.730761
#
# Validation Result:
#  Accuracy: 78.9%, Avg Validation loss: 1.764996
#
# Epoch 60
# -------------------------------
# Train Result:
#  Accuracy: 80.6%, Avg Train loss: 1.730667
#
# Validation Result:
#  Accuracy: 79.2%, Avg Validation loss: 1.755396
#
# Epoch 61
# -------------------------------
# Train Result:
#  Accuracy: 80.7%, Avg Train loss: 1.723609
#
# Validation Result:
#  Accuracy: 79.6%, Avg Validation loss: 1.761842
#
# Epoch 62
# -------------------------------
# Train Result:
#  Accuracy: 81.0%, Avg Train loss: 1.725952
#
# Validation Result:
#  Accuracy: 79.7%, Avg Validation loss: 1.757978
#
# Epoch 63
# -------------------------------
# Train Result:
#  Accuracy: 81.0%, Avg Train loss: 1.721236
#
# Validation Result:
#  Accuracy: 79.5%, Avg Validation loss: 1.758344
#
# Epoch 64
# -------------------------------
# Train Result:
#  Accuracy: 81.2%, Avg Train loss: 1.719637
#
# Validation Result:
#  Accuracy: 79.6%, Avg Validation loss: 1.751931
#
# Epoch 65
# -------------------------------
# Train Result:
#  Accuracy: 81.2%, Avg Train loss: 1.717322
#
# Validation Result:
#  Accuracy: 79.6%, Avg Validation loss: 1.759311
#
# Epoch 66
# -------------------------------
# Train Result:
#  Accuracy: 81.1%, Avg Train loss: 1.715342
#
# Validation Result:
#  Accuracy: 79.7%, Avg Validation loss: 1.757908
#
# Epoch 67
# -------------------------------
# Train Result:
#  Accuracy: 81.3%, Avg Train loss: 1.713414
#
# Validation Result:
#  Accuracy: 79.5%, Avg Validation loss: 1.758569
#
# Epoch 68
# -------------------------------
# Train Result:
#  Accuracy: 81.5%, Avg Train loss: 1.709067
#
# Validation Result:
#  Accuracy: 80.2%, Avg Validation loss: 1.747432
#
# Epoch 69
# -------------------------------
# Train Result:
#  Accuracy: 81.6%, Avg Train loss: 1.705562
#
# Validation Result:
#  Accuracy: 79.7%, Avg Validation loss: 1.754972
#
# Epoch 70
# -------------------------------
# Train Result:
#  Accuracy: 81.7%, Avg Train loss: 1.706076
#
# Validation Result:
#  Accuracy: 80.3%, Avg Validation loss: 1.746702
#
# Epoch 71
# -------------------------------
# Train Result:
#  Accuracy: 81.9%, Avg Train loss: 1.702430
#
# Validation Result:
#  Accuracy: 80.4%, Avg Validation loss: 1.741939
#
# Epoch 72
# -------------------------------
# Train Result:
#  Accuracy: 81.9%, Avg Train loss: 1.696891
#
# Validation Result:
#  Accuracy: 79.8%, Avg Validation loss: 1.746801
#
# Epoch 73
# -------------------------------
# Train Result:
#  Accuracy: 81.6%, Avg Train loss: 1.704199
#
# Validation Result:
#  Accuracy: 80.0%, Avg Validation loss: 1.745106
#
# Epoch 74
# -------------------------------
# Train Result:
#  Accuracy: 82.1%, Avg Train loss: 1.696969
#
# Validation Result:
#  Accuracy: 80.5%, Avg Validation loss: 1.743668
#
# Epoch 75
# -------------------------------
# Train Result:
#  Accuracy: 82.1%, Avg Train loss: 1.692637
#
# Validation Result:
#  Accuracy: 80.1%, Avg Validation loss: 1.743281
#
# Epoch 76
# -------------------------------
# Train Result:
#  Accuracy: 82.2%, Avg Train loss: 1.687860
#
# Validation Result:
#  Accuracy: 80.6%, Avg Validation loss: 1.740003
#
# Epoch 77
# -------------------------------
# Train Result:
#  Accuracy: 82.3%, Avg Train loss: 1.687591
#
# Validation Result:
#  Accuracy: 80.7%, Avg Validation loss: 1.743610
#
# Epoch 78
# -------------------------------
# Train Result:
#  Accuracy: 82.5%, Avg Train loss: 1.681978
#
# Validation Result:
#  Accuracy: 80.8%, Avg Validation loss: 1.741889
#
# Epoch 79
# -------------------------------
# Train Result:
#  Accuracy: 82.5%, Avg Train loss: 1.683628
#
# Validation Result:
#  Accuracy: 80.4%, Avg Validation loss: 1.741034
#
# Epoch 80
# -------------------------------
# Train Result:
#  Accuracy: 82.8%, Avg Train loss: 1.682608
#
# Validation Result:
#  Accuracy: 80.6%, Avg Validation loss: 1.737466
#
# Epoch 81
# -------------------------------
# Train Result:
#  Accuracy: 82.8%, Avg Train loss: 1.682214
#
# Validation Result:
#  Accuracy: 80.8%, Avg Validation loss: 1.734519
#
# Epoch 82
# -------------------------------
# Train Result:
#  Accuracy: 83.0%, Avg Train loss: 1.678454
#
# Validation Result:
#  Accuracy: 80.6%, Avg Validation loss: 1.736628
#
# Epoch 83
# -------------------------------
# Train Result:
#  Accuracy: 83.0%, Avg Train loss: 1.675591
#
# Validation Result:
#  Accuracy: 80.9%, Avg Validation loss: 1.733989
#
# Epoch 84
# -------------------------------
# Train Result:
#  Accuracy: 83.1%, Avg Train loss: 1.676776
#
# Validation Result:
#  Accuracy: 80.8%, Avg Validation loss: 1.733692
#
# Epoch 85
# -------------------------------
# Train Result:
#  Accuracy: 83.0%, Avg Train loss: 1.672316
#
# Validation Result:
#  Accuracy: 80.5%, Avg Validation loss: 1.735300
#
# Epoch 86
# -------------------------------
# Train Result:
#  Accuracy: 83.0%, Avg Train loss: 1.674469
#
# Validation Result:
#  Accuracy: 81.2%, Avg Validation loss: 1.731533
#
# Epoch 87
# -------------------------------
# Train Result:
#  Accuracy: 83.1%, Avg Train loss: 1.673296
#
# Validation Result:
#  Accuracy: 80.9%, Avg Validation loss: 1.728904
#
# Epoch 88
# -------------------------------
# Train Result:
#  Accuracy: 83.4%, Avg Train loss: 1.665621
#
# Validation Result:
#  Accuracy: 81.2%, Avg Validation loss: 1.736369
#
# Epoch 89
# -------------------------------
# Train Result:
#  Accuracy: 83.5%, Avg Train loss: 1.665220
#
# Validation Result:
#  Accuracy: 81.0%, Avg Validation loss: 1.727633
#
# Epoch 90
# -------------------------------
# Train Result:
#  Accuracy: 83.7%, Avg Train loss: 1.659719
#
# Validation Result:
#  Accuracy: 81.1%, Avg Validation loss: 1.726614
#
# Epoch 91
# -------------------------------
# Train Result:
#  Accuracy: 83.7%, Avg Train loss: 1.660547
#
# Validation Result:
#  Accuracy: 81.0%, Avg Validation loss: 1.731015
#
# Epoch 92
# -------------------------------
# Train Result:
#  Accuracy: 83.8%, Avg Train loss: 1.658975
#
# Validation Result:
#  Accuracy: 81.2%, Avg Validation loss: 1.729543
#
# Epoch 93
# -------------------------------
# Train Result:
#  Accuracy: 83.9%, Avg Train loss: 1.655207
#
# Validation Result:
#  Accuracy: 80.9%, Avg Validation loss: 1.728158
#
# Epoch 94
# -------------------------------
# Train Result:
#  Accuracy: 83.9%, Avg Train loss: 1.651695
#
# Validation Result:
#  Accuracy: 81.2%, Avg Validation loss: 1.728883
#
# Epoch 95
# -------------------------------
# Train Result:
#  Accuracy: 83.9%, Avg Train loss: 1.653432
#
# Validation Result:
#  Accuracy: 81.4%, Avg Validation loss: 1.724156
#
# Epoch 96
# -------------------------------
# Train Result:
#  Accuracy: 84.1%, Avg Train loss: 1.649709
#
# Validation Result:
#  Accuracy: 81.7%, Avg Validation loss: 1.725645
#
# Epoch 97
# -------------------------------
# Train Result:
#  Accuracy: 84.2%, Avg Train loss: 1.648288
#
# Validation Result:
#  Accuracy: 81.5%, Avg Validation loss: 1.728097
#
# Epoch 98
# -------------------------------
# Train Result:
#  Accuracy: 84.0%, Avg Train loss: 1.649678
#
# Validation Result:
#  Accuracy: 81.4%, Avg Validation loss: 1.727040
#
# Epoch 99
# -------------------------------
# Train Result:
#  Accuracy: 84.3%, Avg Train loss: 1.647597
#
# Validation Result:
#  Accuracy: 81.5%, Avg Validation loss: 1.722351
#
# Epoch 100
# -------------------------------
# Train Result:
#  Accuracy: 84.4%, Avg Train loss: 1.642568
#
# Validation Result:
#  Accuracy: 81.5%, Avg Validation loss: 1.719429
#
# Done!

# %% [markdown]
# # (C) : Plot The Result

# %%
n_epochs = [*range(epochs)]
plt.figure(figsize=(18,5))
plt.subplot(121)
plt.plot(n_epochs, log['train_loss'])
plt.plot(n_epochs, log['valid_loss'])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title('Loss SGD')
plt.legend(['train loss', 'valid loss'])
plt.subplot(122)
plt.plot(n_epochs, log['train_acc'])
plt.plot(n_epochs, log['valid_acc'])
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title('Accuracy SGD')
plt.legend(['train accuracy', 'valid accuracy'])

# %% [markdown]
# # (D) : Evaluate model On Test data

# %%
print('Accuracy On Test Data Is:')
test_loop(test_loader, model, loss_fn = BinaryCrossEntropy)
# Out:
# Accuracy On Test Data Is:
# Test Result:
#  Accuracy: 80.7%, Avg Test loss: 1.735285

# %%
figure = plt.figure(figsize=(20, 20))
loss_fn = BinaryCrossEntropy
for j in range(9):
    index = random.randint(0, len(test_dataset)-1)
    x, label = test_dataset[index]
    label = label.unsqueeze(0)
    test_loss , test_acc = 0 , 0 
    with torch.no_grad():                       
        img = img.view(x.shape[0], -1)
        pred = model(img)

    figure.add_subplot(9, 1, j+1)
    plt.title(f" True Label: {Class_Name[label.argmax().item()]},  Predicted Label: {Class_Name[pred.argmax().item()]}, Prediction is {Class_Name[label.argmax().item()] == Class_Name[pred.argmax().item()]}  ")
    plt.axis("off")
    plt.imshow(x.squeeze(), cmap="gray")
